# %%
#Levannia Lildhar

class test : 
    def __init__ (self, file, name): 
        import pandas as pd
        self.file = file
        self.name = name
    def reading (self):
        import pandas as pd
        self.data = pd.read_csv(self.file)
        return self.data
    def getName (self): 
        return self.name

liza = test("Health Data.csv", 'liza')
print(liza.reading())
print(liza.getName())
# Out:
#                  Start             Finish  Distance (mi)  Steps (count)
# 0    12-Feb-2017 00:00  13-Feb-2017 00:00       0.559483    1180.000000
# 1    13-Feb-2017 00:00  14-Feb-2017 00:00       2.591677    5353.000000
# 2    14-Feb-2017 00:00  15-Feb-2017 00:00       1.422008    3055.000000
# 3    15-Feb-2017 00:00  16-Feb-2017 00:00       3.953369    7925.000000
# 4    16-Feb-2017 00:00  17-Feb-2017 00:00       1.990246    4130.000000
# 5    17-Feb-2017 00:00  18-Feb-2017 00:00       2.198666    4540.000000
# 6    18-Feb-2017 00:00  19-Feb-2017 00:00       1.164164    2549.000000
# 7    19-Feb-2017 00:00  20-Feb-2017 00:00       0.186647     409.000000
# 8    20-Feb-2017 00:00  21-Feb-2017 00:00       2.209832    4377.000000
# 9    21-Feb-2017 00:00  22-Feb-2017 00:00       3.299301    6549.000000
# 10   22-Feb-2017 00:00  23-Feb-2017 00:00       0.966965    2102.000000
# 11   23-Feb-2017 00:00  24-Feb-2017 00:00       2.239490    4572.000000
# ...
